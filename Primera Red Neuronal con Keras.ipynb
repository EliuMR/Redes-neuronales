# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense

# %%
# cargamos las 4 combinaciones de las compuertas XOR
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")

# y estos son los resultados que se obtienen, en el mismo orden
target_data = np.array([[0],[1],[1],[0]], "float32")
#training_data.shape
target_data.shape
# Out:
# (4, 1)

# %%
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
model.fit(training_data, target_data, epochs=100)
print(' ')
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 573ms/step - loss: 0.2473 - binary_accuracy: 0.5000
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2470 - binary_accuracy: 0.2500
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2468 - binary_accuracy: 0.2500
# Epoch 4/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2466 - binary_accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2464 - binary_accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2462 - binary_accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2460 - binary_accuracy: 0.5000
# Epoch 8/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2458 - binary_accuracy: 0.5000
# Epoch 9/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2456 - binary_accuracy: 0.5000
# Epoch 10/100
# ...

# %%
scores = model.evaluate(training_data, target_data)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 1/1 [==============================] - 0s 232ms/step - loss: 0.2307 - binary_accuracy: 1.0000
#
# binary_accuracy: 100.00%

# %%
print (model.predict(training_data).round())
# Out:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers.core import Dense
 
# cargamos las 4 combinaciones de las compuertas XOR
training_data = np.array([[0,0],[0,1],[1,0],[1,1]], "float32")
 
# y estos son los resultados que se obtienen, en el mismo orden
target_data = np.array([[0],[1],[1],[0]], "float32")
 
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
 
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])
 
model.fit(training_data, target_data, epochs=100)
 
# evaluamos el modelo
scores = model.evaluate(training_data, target_data)
 
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
print (model.predict(training_data).round())
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 330ms/step - loss: 0.2462 - binary_accuracy: 0.7500
# Epoch 2/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2461 - binary_accuracy: 0.5000
# Epoch 3/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2459 - binary_accuracy: 0.5000
# Epoch 4/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2457 - binary_accuracy: 0.5000
# Epoch 5/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2455 - binary_accuracy: 0.5000
# Epoch 6/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2453 - binary_accuracy: 0.5000
# Epoch 7/100
# 1/1 [==============================] - 0s 4ms/step - loss: 0.2451 - binary_accuracy: 0.7500
# Epoch 8/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2449 - binary_accuracy: 0.7500
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2447 - binary_accuracy: 0.7500
# Epoch 10/100
# ...

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers.core import Dense

from sklearn.datasets import make_circles

# %%
#Crear dataset
n=500 #Número de registros de nuestro dataset
p=2 #Cuántas características tenemos sobre cada uno de los registros de nuestros datos
# Por ejemplo si hablaramos de personas. diriamos que tenemos 500 personas y tomamos dos caracteríasticas(p.e. color de piel, altura)
#las neuronas de entrada

X,Y=make_circles(n,factor=0.5,noise=0.05)
#X son los datos que vemos gráficamente
#Y es binario(0,1), que representan la clase a que corresponden esos puntos(i.e si están en un círculo o en el otro)
plt.scatter(X[:,0],X[:,1])
plt.axis('equal')
plt.show()
plt.savefig('Data_set')
Y=Y[:,np.newaxis]#Rescribimos Y para que tenga una dimension (500,1) y no (500,)

# %%
model = Sequential()
model.add(Dense(16, input_dim=2, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='mean_squared_error',
              optimizer='adam',
              metrics=['binary_accuracy'])

# %%
model.fit(X, Y, epochs=50)
# Out:
# Epoch 1/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2792 - binary_accuracy: 0.4662
# Epoch 2/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2745 - binary_accuracy: 0.4719
# Epoch 3/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2658 - binary_accuracy: 0.5007
# Epoch 4/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2689 - binary_accuracy: 0.4505
# Epoch 5/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2600 - binary_accuracy: 0.4768
# Epoch 6/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2574 - binary_accuracy: 0.4640
# Epoch 7/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2549 - binary_accuracy: 0.4321
# Epoch 8/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2527 - binary_accuracy: 0.4699
# Epoch 9/50
# 16/16 [==============================] - 0s 1ms/step - loss: 0.2495 - binary_accuracy: 0.4811
# Epoch 10/50
# ...

# %%
scores = model.evaluate(X, Y)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 16/16 [==============================] - 0s 1ms/step - loss: 0.1568 - binary_accuracy: 1.0000
#
# binary_accuracy: 100.00%

# %%
from keras.models import model_from_json
# serializar el modelo a JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serializar los pesos a HDF5
model.save_weights("model.h5")
print("Modelo Guardado!")
 
# mas tarde...
 
# cargar json y crear el modelo
json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
#loaded_model = loaded_model_json
# cargar pesos al nuevo modelo
loaded_model.load_weights("model.h5")
print("Cargado modelo desde disco.")
 
# Compilar modelo cargado y listo para usar.
loaded_model.compile(loss='mean_squared_error', optimizer='adam', metrics=['binary_accuracy'])
# Out:
# Modelo Guardado!
# Cargado modelo desde disco.

# %%
score = loaded_model.evaluate(X, Y, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))
# Out:
# binary_accuracy: 100.00%

# %%
prueba=loaded_model.predict(X).round()
