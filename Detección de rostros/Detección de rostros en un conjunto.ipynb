# %%
import cv2
from google.colab.patches import cv2_imshow
faceClassif = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
image = cv2.imread('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/f.jpg')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = faceClassif.detectMultiScale(gray,
  scaleFactor=1.1,
  minNeighbors=1,
  minSize=(100,100),
  maxSize=(800,800))
print(faces)
for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)

cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[407 157 138 138]
#  [520 177 143 143]
#  [315 317 132 132]
#  [611 342 134 134]]
# <PIL.Image.Image image mode=RGB size=1000x667 at 0x7F1757814F50>

# %%
import cv2
from google.colab.patches import cv2_imshow
faceClassif = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
image = cv2.imread('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/f.jpg')
imageAux=image.copy()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = faceClassif.detectMultiScale(gray,
  scaleFactor=1.1,
  minNeighbors=1,
  minSize=(100,100),
  maxSize=(800,800))
contador=0

for (x,y,w,h) in faces:
  cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
  rostro=imageAux[y:y+h,x:x+w]
  rostro=cv2.resize(rostro,(50,50),interpolation=cv2.INTER_CUBIC)
  cv2.imwrite('rostro_{}.jpg'.format(contador),rostro)
  contador=contador+1
  cv2_imshow(rostro)
  cv2_imshow(image)
  cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
import cv2
from google.colab.patches import cv2_imshow
faceClassif = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")
image = cv2.imread('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/f.jpg')
imageAux=image.copy()
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
faces = faceClassif.detectMultiScale(gray,
  scaleFactor=1.1,
  minNeighbors=1,
  minSize=(100,100),
  maxSize=(800,800))
contador=0

for (x,y,w,h) in faces:
  #cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
  rostro=imageAux[y:y+h,x:x+w]
  rostro=cv2.resize(rostro,(50,50),interpolation=cv2.INTER_CUBIC)
  cv2.imwrite('rostro_{}.jpg'.format(contador),rostro)
  contador=contador+1
  cv2_imshow(rostro)
  #cv2_imshow(image)
  #cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F1755CE1D90>
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F1755CE1E10>
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F1755CE1D90>
# <PIL.Image.Image image mode=RGB size=50x50 at 0x7F1755CE1D10>

# %%
#Un dataset de varias familias
import cv2
import os

imagesPath='/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/conjuntos de familias'
imagesPathList=os.listdir(imagesPath)
print(imagesPathList)
#Creamos donde guaradamos las imagenes
if not os.path.exists('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/Rostros encontrados'):
  print('Carpeta creada ')
  os.makedirs('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/Rostros encontrados')
from google.colab.patches import cv2_imshow
faceClassif = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")


#Pasamos por cada imagen del directorio y recortamos cada foto individualmente
count=0

for imageName in imagesPathList:
  print('imageName=',imageName)
  image=cv2.imread(imagesPath+'/'+imageName)
  imageAux=image.copy()
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  faces = faceClassif.detectMultiScale(gray,
  scaleFactor=1.1,
  minNeighbors=1,
  minSize=(100,100),
  maxSize=(150,150))
  for (x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,255,0),2)
  cv2.rectangle(image,(10,5),(450,25),(255,255,355),1)
  cv2.putText(image,'Presione s para almacenar',(10,20),2,0.5,(128,0,255),1,cv2.LINE_AA)
  cv2_imshow(image)
  k=cv2.waitKey(0)
  for (x,y,w,h) in faces:
      rostro=imageAux[y:y+h,x:x+w]
      rostro=cv2.resize(rostro,(150,150),interpolation=cv2.INTER_CUBIC)
      #cv2_imshow(rostro)
      #cv2.waitKey(0)
      cv2.imwrite('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/Rostros encontrados/Rostro_{}.jpg'.format(count),rostro)
      count=count+1
  '''
  if k==ord('s'):
    for (x,y,w,h) in faces:
      rostro=imageAux[y:y+h,x:x+w]
      rostro=cv2.resize(rostro,(150,150),inteporlation=cv2.INTER_CUBIC)
      cv2_imshow(rostro)
      cv2.waitKey(0)
      cv2.imwrite('/content/drive/MyDrive/archive.zip (Unzipped Files)/Detección de rostros/Rostros encontrados/Rostro_{}.jpg'.format(count),rostro)
      count=count+1
      #Presionar scape para salir 
  else k=27:
    break
      '''
  
cv2.destroyAllWindows()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
