# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import keras
from keras.utils import to_categorical
from keras.models import Sequential,Input,Model
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers.normalization import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU

# %%
url='https://www.kaggle.com/pranavraikokte/covid19-image-dataset'

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-f39ed053-161e-42b2-95c3-0baf0d96ff29" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f39ed053-161e-42b2-95c3-0baf0d96ff29">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json
# {'kaggle.json': b'{"username":"hieskertronco","key":"112e177620313de7cf33565ad38ca3fc"}'}

# %%
! mkdir ~/.kaggle

# %%
! cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets list
# Out:
# ...
# ref                                                         title                                              size  lastUpdated          downloadCount
# ----------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------
# gpreda/reddit-vaccine-myths                                 Reddit Vaccine Myths                              223KB  2021-04-09 08:39:14           2320
# crowww/a-large-scale-fish-dataset                           A Large Scale Fish Dataset                          3GB  2021-02-17 16:10:44           1337
# dhruvildave/wikibooks-dataset                               Wikibooks Dataset                                   1GB  2021-02-18 10:08:27           1027
# imsparsh/musicnet-dataset                                   MusicNet Dataset                                   22GB  2021-02-18 14:12:19            480
# ...

# %%
! kaggle datasets download -d pranavraikokte/covid19-image-dataset
# Out:
# ...
#  91% 144M/158M [00:02<00:00, 49.5MB/s]
# 100% 158M/158M [00:02<00:00, 65.7MB/s]

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# !mkdir '/content/drive/MyDrive/archive.zip (Unzipped Files)/covid'

# %%
# !unzip covid19-image-dataset.zip -d '/content/drive/MyDrive/archive.zip (Unzipped Files)/covid'
# Out:
# Archive:  covid19-image-dataset.zip
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0100.jpeg
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0102.jpeg
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0105.png
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0106.jpeg
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0108.jpeg
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0111.jpg
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0112.jpg
#   inflating: /content/drive/MyDrive/archive.zip (Unzipped Files)/covid/Covid19-dataset/test/Covid/0113.jpg
# ...

# %%
https://platzi.com/tutoriales/1794-pandas/6926-usando-la-api-de-kaggle-con-google-colab-para-carga-y-descarga-de-datasets/
